# %%
import pandas as pd

# %%
corona_veri = pd.read_csv("turkey_covid19_all.csv")
corona_veri
# Out:
#    Country/Region  Province/State  Latitude  Longitude  Confirmed  Recovered  \
# 0          Turkey             NaN   38.9637    35.2433        1.0        0.0
# 1          Turkey             NaN   38.9637    35.2433        1.0        0.0
# 2          Turkey             NaN   38.9637    35.2433        5.0        0.0
# 3          Turkey             NaN   38.9637    35.2433        5.0        0.0
# 4          Turkey             NaN   38.9637    35.2433        6.0        0.0
# 5          Turkey             NaN   38.9637    35.2433       18.0        0.0
# 6          Turkey             NaN   38.9637    35.2433       47.0        0.0
# 7          Turkey             NaN   38.9637    35.2433       98.0        0.0
# 8          Turkey             NaN   38.9637    35.2433      192.0        0.0
# 9          Turkey             NaN   38.9637    35.2433      359.0        0.0
# 10         Turkey             NaN   38.9637    35.2433      670.0        0.0
# ...

# %%
import matplotlib as plt
# %matplotlib inline

# %%
corona_veri.Confirmed.plot();

# %%
corona_veri.Confirmed.hist();

# %%
corona_veri["Date"] =  pd.to_datetime(corona_veri["Date"],format='%Y-%m-%d')

# %%
corona_veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  48 non-null     object
#  1   Province/State  0 non-null      float64
#  2   Latitude        48 non-null     float64
#  3   Longitude       48 non-null     float64
#  4   Confirmed       48 non-null     float64
#  5   Recovered       48 non-null     float64
#  6   Deaths          48 non-null     float64
#  7   Date            48 non-null     datetime64[ns]
#  8   Tests           48 non-null     int64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
import matplotlib as plt
# %matplotlib inline
corona_veri["Date"] =  pd.to_datetime(corona_veri["Date"],format='%Y-%m-%d')
corona_veri.plot(y="Tests",x="Date");

# %%
corona_veri.head()
# Out:
#   Country/Region  Province/State  Latitude  Longitude  Confirmed  Recovered  \
# 0         Turkey             NaN   38.9637    35.2433        1.0        0.0
# 1         Turkey             NaN   38.9637    35.2433        1.0        0.0
# 2         Turkey             NaN   38.9637    35.2433        5.0        0.0
# 3         Turkey             NaN   38.9637    35.2433        5.0        0.0
# 4         Turkey             NaN   38.9637    35.2433        6.0        0.0
#
#    Deaths       Date  Tests
# 0     0.0 2020-03-11      0
# 1     0.0 2020-03-12      0
# 2     0.0 2020-03-13      0
# 3     0.0 2020-03-14      0
# 4     0.0 2020-03-15      0

# %%
import random as rnd 
corona_veri["Yardım"] = pd.Series([ "$ "+str(rnd.randint(0,500)) for i in range(len(corona_veri))])
corona_veri["Yardım"].dtypes
# Out:
# dtype('O')

# %%
corona_veri["Yardım"] = corona_veri["Yardım"].str.replace('[\$\,\.]','').astype(int)

# %%
corona_veri["Country/Region"] = corona_veri["Country/Region"].str.replace("Turkey",'Türkiye')
corona_veri.head()
# Out:
#   Country/Region  Province/State  Latitude  Longitude  Confirmed  Recovered  \
# 0        Türkiye             NaN   38.9637    35.2433        1.0        0.0
# 1        Türkiye             NaN   38.9637    35.2433        1.0        0.0
# 2        Türkiye             NaN   38.9637    35.2433        5.0        0.0
# 3        Türkiye             NaN   38.9637    35.2433        5.0        0.0
# 4        Türkiye             NaN   38.9637    35.2433        6.0        0.0
#
#    Deaths       Date  Tests  Yardım
# 0     0.0 2020-03-11      0     223
# 1     0.0 2020-03-12      0      28
# 2     0.0 2020-03-13      0     456
# 3     0.0 2020-03-14      0      26
# 4     0.0 2020-03-15      0      44

# %%
tum_corona = pd.read_csv("covid_19_clean_complete.csv")
tum_corona.tail()
# Out:
#                   Province/State         Country/Region        Lat       Long  \
# 25671  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 25672                        NaN            South Sudan   6.877000  31.307000
# 25673                        NaN         Western Sahara  24.215500 -12.885800
# 25674                        NaN  Sao Tome and Principe   0.186360   6.613081
# 25675                        NaN                  Yemen  15.552727  48.516388
#
#           Date  Confirmed  Deaths  Recovered
# 25671  4/28/20          1       0          0
# 25672  4/28/20         34       0          0
# 25673  4/28/20          6       0          5
# 25674  4/28/20          8       0          4
# 25675  4/28/20          1       0          0

# %%
tum_corona[tum_corona["Country/Region"] == "Turkey"]
# Out:
#       Province/State Country/Region      Lat     Long     Date  Confirmed  \
# 213              NaN         Turkey  38.9637  35.2433  1/22/20          0
# 475              NaN         Turkey  38.9637  35.2433  1/23/20          0
# 737              NaN         Turkey  38.9637  35.2433  1/24/20          0
# 999              NaN         Turkey  38.9637  35.2433  1/25/20          0
# 1261             NaN         Turkey  38.9637  35.2433  1/26/20          0
# ...              ...            ...      ...      ...      ...        ...
# 24579            NaN         Turkey  38.9637  35.2433  4/24/20     104912
# 24841            NaN         Turkey  38.9637  35.2433  4/25/20     107773
# 25103            NaN         Turkey  38.9637  35.2433  4/26/20     110130
# 25365            NaN         Turkey  38.9637  35.2433  4/27/20     112261
# 25627            NaN         Turkey  38.9637  35.2433  4/28/20     114653
#
#        Deaths  Recovered
# 213         0          0
# 475         0          0
# ...

# %%
tum_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25676 entries, 0 to 25675
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  7840 non-null   object
#  1   Country/Region  25676 non-null  object
#  2   Lat             25676 non-null  float64
#  3   Long            25676 non-null  float64
#  4   Date            25676 non-null  object
#  5   Confirmed       25676 non-null  int64
#  6   Deaths          25676 non-null  int64
#  7   Recovered       25676 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.6+ MB

# %%
tum_corona_yed = tum_corona.copy()

# %%
tum_corona1 = tum_corona.copy()
tum_corona1["Province/State"].describe()
# Out:
# count        7840
# unique         80
# top       Jiangsu
# freq           98
# Name: Province/State, dtype: object

# %%
tum_corona1.dropna()
# Out:
#                      Province/State  Country/Region      Lat      Long  \
# 8      Australian Capital Territory       Australia -35.4735  149.0124
# 9                   New South Wales       Australia -33.8688  151.2093
# 10               Northern Territory       Australia -12.4634  130.8456
# 11                       Queensland       Australia -28.0167  153.4000
# 12                  South Australia       Australia -34.9285  138.6007
# ...                             ...             ...      ...       ...
# 25662                      Anguilla  United Kingdom  18.2206  -63.0686
# 25663        British Virgin Islands  United Kingdom  18.4207  -64.6400
# 25664      Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 25670   Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 25671     Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#           Date  Confirmed  Deaths  Recovered
# 8      1/22/20          0       0          0
# ...

# %%
tum_corona1.dropna(inplace=True)

# %%
tum_corona1
# Out:
#                      Province/State  Country/Region      Lat      Long  \
# 8      Australian Capital Territory       Australia -35.4735  149.0124
# 9                   New South Wales       Australia -33.8688  151.2093
# 10               Northern Territory       Australia -12.4634  130.8456
# 11                       Queensland       Australia -28.0167  153.4000
# 12                  South Australia       Australia -34.9285  138.6007
# ...                             ...             ...      ...       ...
# 25662                      Anguilla  United Kingdom  18.2206  -63.0686
# 25663        British Virgin Islands  United Kingdom  18.4207  -64.6400
# 25664      Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 25670   Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 25671     Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#           Date  Confirmed  Deaths  Recovered
# 8      1/22/20          0       0          0
# ...

# %%
tum_corona1.reset_index()
# Out:
#       index                Province/State  Country/Region      Lat      Long  \
# 0         8  Australian Capital Territory       Australia -35.4735  149.0124
# 1         9               New South Wales       Australia -33.8688  151.2093
# 2        10            Northern Territory       Australia -12.4634  130.8456
# 3        11                    Queensland       Australia -28.0167  153.4000
# 4        12               South Australia       Australia -34.9285  138.6007
# ...     ...                           ...             ...      ...       ...
# 7835  25662                      Anguilla  United Kingdom  18.2206  -63.0686
# 7836  25663        British Virgin Islands  United Kingdom  18.4207  -64.6400
# 7837  25664      Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 7838  25670   Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 7839  25671     Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#          Date  Confirmed  Deaths  Recovered
# ...

# %%
tum_corona1.reset_index(drop=True,inplace=True)
tum_corona1
# Out:
#                     Province/State  Country/Region      Lat      Long  \
# 0     Australian Capital Territory       Australia -35.4735  149.0124
# 1                  New South Wales       Australia -33.8688  151.2093
# 2               Northern Territory       Australia -12.4634  130.8456
# 3                       Queensland       Australia -28.0167  153.4000
# 4                  South Australia       Australia -34.9285  138.6007
# ...                            ...             ...      ...       ...
# 7835                      Anguilla  United Kingdom  18.2206  -63.0686
# 7836        British Virgin Islands  United Kingdom  18.4207  -64.6400
# 7837      Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 7838   Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 7839     Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#          Date  Confirmed  Deaths  Recovered
# 0     1/22/20          0       0          0
# ...

# %%
tum_corona["Province/State"].fillna("Yok",inplace=False)
# Out:
# 0                              Yok
# 1                              Yok
# 2                              Yok
# 3                              Yok
# 4                              Yok
#                    ...
# 25671    Saint Pierre and Miquelon
# 25672                          Yok
# 25673                          Yok
# 25674                          Yok
# 25675                          Yok
# Name: Province/State, Length: 25676, dtype: object

# %%
tum_corona["Normal"] = False
tum_corona = tum_corona.drop("Normal",axis=1)
tum_corona
# Out:
#                   Province/State         Country/Region        Lat       Long  \
# 0                            NaN            Afghanistan  33.000000  65.000000
# 1                            NaN                Albania  41.153300  20.168300
# 2                            NaN                Algeria  28.033900   1.659600
# 3                            NaN                Andorra  42.506300   1.521800
# 4                            NaN                 Angola -11.202700  17.873900
# ...                          ...                    ...        ...        ...
# 25671  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 25672                        NaN            South Sudan   6.877000  31.307000
# 25673                        NaN         Western Sahara  24.215500 -12.885800
# 25674                        NaN  Sao Tome and Principe   0.186360   6.613081
# 25675                        NaN                  Yemen  15.552727  48.516388
#
# ...

# %%
tum_corona_test = tum_corona.sample(frac=0.01)
tum_corona_test
# Out:
#       Province/State    Country/Region      Lat      Long     Date  \
# 24068            NaN        Uzbekistan  41.3775   64.5853  4/22/20
# 6588        Manitoba            Canada  53.7609  -98.8139  2/16/20
# 6611       Hong Kong             China  22.3000  114.2000  2/16/20
# 21910            NaN           Namibia -22.9576   18.4904  4/14/20
# 19996            NaN  Congo (Kinshasa)  -4.0383   21.7587   4/7/20
# ...              ...               ...      ...       ...      ...
# 17324            NaN        Cabo Verde  16.5388  -23.0418  3/28/20
# 12913         Shanxi             China  37.5777  112.2922  3/11/20
# 17787            NaN           Grenada  12.1165  -61.6790  3/29/20
# 9222          Fujian             China  26.0789  117.9874  2/26/20
# 7166   Faroe Islands           Denmark  61.8926   -6.9118  2/18/20
#
#          Confirmed  Deaths  Recovered
# 24068  1716.000000       7        450
# 6588   2621.362401       0          0
# 6611     57.000000       1          2
# ...

# %%
tum_corona
# Out:
#               Country/Region        Lat       Long     Date    Confirmed  \
# 0                Afghanistan  33.000000  65.000000  1/22/20  2621.362401
# 1                    Albania  41.153300  20.168300  1/22/20  2621.362401
# 2                    Algeria  28.033900   1.659600  1/22/20  2621.362401
# 3                    Andorra  42.506300   1.521800  1/22/20  2621.362401
# 4                     Angola -11.202700  17.873900  1/22/20  2621.362401
# ...                      ...        ...        ...      ...          ...
# 25671                 France  46.885200 -56.315900  4/28/20     1.000000
# 25672            South Sudan   6.877000  31.307000  4/28/20    34.000000
# 25673         Western Sahara  24.215500 -12.885800  4/28/20     6.000000
# 25674  Sao Tome and Principe   0.186360   6.613081  4/28/20     8.000000
# 25675                  Yemen  15.552727  48.516388  4/28/20     1.000000
#
#        Deaths  Recovered
# 0           0          0
# 1           0          0
# ...

# %%
tum_corona.reset_index(inplace=True)

# %%
tum_corona["level_0"] = tum_corona["level_0"].apply(lambda x : x*5)

# %%
tum_corona
# Out:
#        level_0  index         Country/Region        Lat       Long     Date  \
# 0            0      0            Afghanistan  33.000000  65.000000  1/22/20
# 1           25      1                Albania  41.153300  20.168300  1/22/20
# 2           50      2                Algeria  28.033900   1.659600  1/22/20
# 3           75      3                Andorra  42.506300   1.521800  1/22/20
# 4          100      4                 Angola -11.202700  17.873900  1/22/20
# ...        ...    ...                    ...        ...        ...      ...
# 25671   641775  25671                 France  46.885200 -56.315900  4/28/20
# 25672   641800  25672            South Sudan   6.877000  31.307000  4/28/20
# 25673   641825  25673         Western Sahara  24.215500 -12.885800  4/28/20
# 25674   641850  25674  Sao Tome and Principe   0.186360   6.613081  4/28/20
# 25675   641875  25675                  Yemen  15.552727  48.516388  4/28/20
#
#          Confirmed  Deaths  Recovered
# ...
